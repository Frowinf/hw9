# %% [markdown]
# # CPSC 330 - Applied Machine Learning
#
# ## Homework 9: Communication

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# <div class="alert alert-info">
#
# ## Submission instructions
# <hr>
# rubric={points:2}
#
# Follow the [homework submission instructions](https://github.com/UBC-CS/cpsc330-2024W1/blob/main/docs/homework_instructions.md).
#
# **You may work in a group on this homework and submit your assignment as a group.** Below are some instructions on working as a group.
# - The maximum group size is 2.
# - Use group work as an opportunity to collaborate and learn new things from each other.
# - Be respectful to each other and make sure you understand all the concepts in the assignment well.
# - It's your responsibility to make sure that the assignment is submitted by one of the group members before the deadline.
# - You can find the instructions on how to do group submission on Gradescope [here](https://help.gradescope.com/article/m5qz2xsnjy-student-add-group-members).
#
#
# When you are ready to submit your assignment do the following:
#
# 1. Run all cells in your notebook to make sure there are no errors by doing `Kernel -> Restart Kernel and Clear All Outputs` and then `Run -> Run All Cells`.
# 2. Notebooks with cell execution numbers out of order or not starting from “1” will have marks deducted. Notebooks without the output displayed may not be graded at all (because we need to see the output in order to grade your work).
# 3. Upload the assignment using Gradescope's drag and drop tool. Check out this [Gradescope Student Guide](https://lthub.ubc.ca/guides/gradescope-student-guide/) if you need help with Gradescope submission.
# 4. Make sure that the plots and output are rendered properly in your submitted file.
# 5. If the .ipynb file is too big and doesn't render on Gradescope, also upload a pdf or html in addition to the .ipynb.

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ## Exercise 1: Communication
# <hr>

# %% [markdown]
# ### 1.1 Blog post
# rubric={points:26}
#
# Write up your analysis from hw5 or any other assignment or your side project on machine learning in a "blog post" or report format. It's fine if you just write it here in this notebook. Alternatively, you can publish your blog post publicly and include a link here. (See exercise 1.3.) The target audience for your blog post is someone like yourself right before you took this course. They don't necessarily have ML knowledge, but they have a solid foundation in technical matters. The post should focus on explaining **your results and what you did** in a way that's understandable to such a person, **not** a lesson trying to teach someone about machine learning. Again: focus on the results and why they are interesting; avoid pedagogical content.
#
# Your post must include the following elements (not necessarily in this order):
#
# - Description of the problem/decision.
# - Description of the dataset (the raw data and/or some EDA).
# - Description of the model.
# - Description your results, both quantitatively and qualitatively. Make sure to refer to the original problem/decision.
# - A section on caveats, describing at least 3 reasons why your results might be incorrect, misleading, overconfident, or otherwise problematic. Make reference to your specific dataset, model, approach, etc. To check that your reasons are specific enough, make sure they would not make sense, if left unchanged, to most students' submissions; for example, do not just say "overfitting" without explaining why you might be worried about overfitting in your specific case.
# - At least 3 visualizations. These visualizations must be embedded/interwoven into the text, not pasted at the end. The text must refer directly to each visualization. For example "as shown below" or "the figure demonstrates" or "take a look at Figure 1", etc. It is **not** sufficient to put a visualization in without referring to it directly.
#
# A reasonable length for your entire post would be **800 words**. The maximum allowed is **1000 words**.

# %% [markdown]
# #### Example blog posts
#
# Here are some examples of applied ML blog posts that you may find useful as inspiration. The target audiences of these posts aren't necessarily the same as yours, and these posts are longer than yours, but they are well-structured and engaging. You are **not required to read these** posts as part of this assignment - they are here only as examples if you'd find that useful.
#
# From the UBC Master of Data Science blog, written by a past student:
#
# - https://ubc-mds.github.io/2019-07-26-predicting-customer-probabilities/
#
# This next one uses R instead of Python, but that might be good in a way, as you can see what it's like for a reader that doesn't understand the code itself (the target audience for your post here):
#
# - https://rpubs.com/RosieB/taylorswiftlyricanalysis
#
# Finally, here are a couple interviews with winners from Kaggle competitions. The format isn't quite the same as a blog post, but you might find them interesting/relevant:
#
# - https://medium.com/kaggle-blog/instacart-market-basket-analysis-feda2700cded
# - https://medium.com/kaggle-blog/winner-interview-with-shivam-bansal-data-science-for-good-challenge-city-of-los-angeles-3294c0ed1fb2

# %% [markdown]
# #### A note on plagiarism
#
# You may **NOT** include text or visualizations that were not written/created by you. If you are in any doubt as to what constitutes plagiarism, please just ask. For more information see the [UBC Academic Misconduct policies](http://www.calendar.ubc.ca/vancouver/index.cfm?tree=3,54,111,959). Please don't copy this from somewhere or ask Generative AI to write it for you 🙏.

# %% [markdown]
# <br><br>

# %% [markdown]
# **Credit Default Prediction Modelling**
#
# **Introduction**
# Credit default occurs when an individual fails to repay their credit card debts. This issue can cause banks to experience monetary losses. Because of this, being able to successfully predict credit default can be highly beneficial to banks. As data collection improves and the availability of data increases, leveraging machine learning to develop predictive models for credit default becomes more and more beneficial for banks. This project aimed to create a predictive model using machine learning to estimate and predict whether or not a credit card client is likely to default on their credit card debt in the upcoming month.

# %% [markdown]
# **The Dataset**
# We used the UCI Default of Credit Card Clients dataset. It contains 30,000 records and 24 predictive variables. These include demographic characteristics such as age, gender, marital status, and education, financial indicators such as credit limit, bill statements, and payments over the last six months, and repayment status variables , Pay_0 to Pay_6, which show past delinquencies. Our target variable was default.payment.next.month, a binary outcome which indicates whether or not a customer defaulted in the following billing cycle.
# Exploratory data analysis revealed several trends. One thing we learned was that the dataset had a class imbalance, with ~22% of data points being classified as credit default. This can be seen in the visualization below.
#  Exploratory data analysis also revealed that clients with recent payment issues(high pay_0 values), are more likely to default than those without recent payment issues. It also revealed that as people get more educated, their risk of default decreases.

# %% [markdown]
# ## Figure 1

# %%
Image("Vis3.png")

# %% [markdown]
# **Modeling**
# We began with a DummyClassifier as a baseline model, which simply predicted the majority class (non-default) every time. As expected, it achieved a high accuracy of 0.78,  but an F1 score of 0.00 on the minority class (credit default).
# Next, we evaluated the following four machine learning models:
#  - Logistic Regression
# - K-Nearest Neighbors (KNN)
# - Support Vector Classifier (SVC)
# - Random Forest (selected as our final model)
#
# Each model was embedded in a pipeline for preprocessing. We standardized numerical features and one-hot encoded categorical ones. We also experimented with combining features such as total bill amount and total payments. Hyperparameter tuning was done using RandomizedSearchCV with 5-fold cross-validation while optimizing for F1 score.

# %% [markdown]
# **Results**
# The Random Forest model outperformed the other models. It achieved a test F1 score of 0.48 and a test accuracy of 0.82. The final confusion matrix showed 745 true positives out of 1,991 defaulters as shown in figure 2. It had  a recall of 0.37 and precision of 0.68 for the default class. These results showed a strong improvement over simpler models, especially the baseline.
# To increase interpretability, we analyzed feature importances as seen in figure 3. The top features were:
# PAY_0 (most recent payment delay status),
# TOTAL_BILL_AMT (total billed amount over six months),
# TOTAL_PAY_AMT (cumulative past repayments),
# AGE,
# and LIMIT_BAL (credit limit).

# %% [markdown]
# ## Figure 2

# %%
Image("Vis2.png")

# %% [markdown]
# ## Figure 3

# %%
Image("Vis3.png")

# %% [markdown]
# **Caveats**
# Hard to interpret: While the Random Forest model gave the best results, it's harder to interpret than simpler models. Using a tool such as SHAP could help break down the model and increase interoperability.
#
# Time based data: Our features include several months of payment history. It is possible that the data required for the model to predict credit default is only accessible too late.  There’s a risk of using information that might not be available until the credit default is already bound to happen.
#
# Fairness concerns: Features like education,marital status, or age could unintentionally reflect social biases. If the model were to be used in real life application the model should be carefully reviewed to make sure there are no unfair biases.

# %% [markdown]
# ### 1.2 Effective communication technique
# rubric={points:4}
#
# Describe one effective communication technique that you used in your post, or an aspect of the post that you are particularly satisfied with. (Max 3 sentences.)

# %% [markdown]
# One effective communication technique I used was structuring the blog post into clear and titled sections that follow the steps of a machine learning project. This helped make the content easy to follow especially for readers who may not have a lot of machine learning experience.

# %% [markdown]
# ### (optional, not for marks) 1.3
#
# Publish your blog post from 1.1 publicly using a tool like [Quarto](https://quarto.org/), or somewhere like medium.com, and paste a link here. Be sure to pick a tool in which code and code output look reasonable. This link could be a useful line on your resume!

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ## Exercise 2: Your takeaway from the course
# rubric={points:2}
#
# **Your tasks:**
#
# - Reflect on your journey through this course. Please identify and elaborate on at least three key concepts or experiences where you had an "aha" moment. How would you use the concepts learned in this course in your personal projects or how would you approach your past projects differently based on the insights gained in this course? We encourage you to dig deep and share your genuine reflections.
#
# > Please write thoughtful answers. We are looking forward to reading them 🙂.

# %% [markdown]
# One major takeaway from this course was learning how to evaluate models beyond accuracy. Learning metrics such as F1 score, precision, and recall helped me realize that a model that has high accuracy may not actually be useful. Another concept I learned was interperability. While more complex models tend to have better performance, the interoperability tends to go down, which is important for understanding it's predictions and catching biases. A third key concept was the importance of data. A predictive model can only be as good as the data. If the data is unreliable, or does not include relevant features, the predictive model will also be unreliable.

# %% [markdown]
# **Before submitting your assignment, please make sure you have followed all the instructions in the Submission instructions section at the top.**

# %% [markdown]
# ### Congratulations 👏👏
#
# That's all for the assignments! Congratulations on finishing all homework assignments!

# %%
from IPython.display import Image

Image("img/eva-congrats.png")
